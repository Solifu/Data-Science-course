# %% [markdown]
# # Exercise scraping minifigs
#
# Minifigs are the figurines included in legosets. There are many of them, and some of them have a real personality, while others are more generic. You can find all of them on the [brickset-website](https://brickset.com/browse/minifigs). Note that we won't be downloading all the images, as that would stress the bandwidth of this free website way to much. The goal therefore is to create a list of URL's, divided by theme.
#
# If you want you can still download the image files later on, print them all individually on A4 pages and redecorate your room.
#
# But back to code. First step is including the libraries.

# %%
# ! pip install requests
# ! pip install beautifulsoup4

import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ## Step 1
#
# Request the content of the page https://brickset.com/browse/minifigs.
# Show the first and last 100 characters.

# %%
import requests
from bs4 import BeautifulSoup


# URL of the page
url = "https://brickset.com/browse/minifigs"

# Add headers to mimic a browser (helps avoid blocking)
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# Request the page
response = requests.get(url, headers=headers)

# Get the content as text
page_content = response.text

# Show first 100 characters
print("First 100 characters:")
print(page_content[:100])

# Show last 100 characters
print("\nLast 100 characters:")
print(page_content[-100:])
# Out:
# First 100 characters:
#
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!
#
# Last 100 characters:
# oading'!==document.readyState&&(document.onreadystatechange=e,c())}}}})();</script></body>
#  </html>

# %% [markdown]
# ## Step 2
#
# So we can see we have the basic site content now. The actual site is a page with links to all the different themes, and we need all these links to go and fetch the page behind it. We reach back to trusty old Chrome Inspect to see what part of the website we're interested in:
#
# ![](images/2022-03-07-21-23-48.png)
#
# We can skip everything not in ```"<div class="content">"```.
#
# Write the code to create a list of tuples.  Each tuple contains the category name and the url of the page showing the corresponding minifigs.
#
# ![](images/minifig_part2.PNG)

# %%
url = "https://brickset.com/browse/minifigs"
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36'}

response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')

# Find the content div
content_div = soup.find('div', class_='content')

# Create list of tuples (category name, url)
categories = []

# Find all links inside the content div
for link in content_div.find_all('a'):
    name = link.text.strip()
    href = link.get('href')
    
    # Only add if it's a category link (not empty and contains 'minifigs')
    if name and href and 'minifigs' in href:
        full_url = "https://brickset.com" + href
        categories.append((name, full_url))

# Print the results
for name, url in categories:
    print(name, "->", url)
# Out:
# Adventurers -> https://brickset.com/minifigs/category-Adventurers
# Agents -> https://brickset.com/minifigs/category-Agents
# Alpha Team -> https://brickset.com/minifigs/category-Alpha-Team
# Animal Crossing -> https://brickset.com/minifigs/category-Animal-Crossing
# Aquazone -> https://brickset.com/minifigs/category-Aquazone
# Architecture -> https://brickset.com/minifigs/category-Architecture
# Atlantis -> https://brickset.com/minifigs/category-Atlantis
# Avatar -> https://brickset.com/minifigs/category-Avatar
# Avatar The Last Airbender -> https://brickset.com/minifigs/category-Avatar-The-Last-Airbender
# Back to the Future -> https://brickset.com/minifigs/category-Back-to-the-Future
# Basic -> https://brickset.com/minifigs/category-Basic
# Batman I -> https://brickset.com/minifigs/category-Batman-I
# Belville -> https://brickset.com/minifigs/category-Belville
# BIONICLE -> https://brickset.com/minifigs/category-BIONICLE
# Bluey -> https://brickset.com/minifigs/category-Bluey
# BrickLink Designer Program -> https://brickset.com/minifigs/category-BrickLink-Designer-Program
# Building Bigger Thinking -> https://brickset.com/minifigs/category-Building-Bigger-Thinking
# Cars -> https://brickset.com/minifigs/category-Cars
# Castle -> https://brickset.com/minifigs/category-Castle
# Clikits -> https://brickset.com/minifigs/category-Clikits
# Collectible Minifigures -> https://brickset.com/minifigs/category-Collectible-Minifigures
# DC Super Hero Girls -> https://brickset.com/minifigs/category-DC-Super-Hero-Girls
# Despicable Me and Minions -> https://brickset.com/minifigs/category-Despicable-Me-and-Minions
# Dimensions -> https://brickset.com/minifigs/category-Dimensions
# Dino -> https://brickset.com/minifigs/category-Dino
# Dino Attack -> https://brickset.com/minifigs/category-Dino-Attack
# Discovery -> https://brickset.com/minifigs/category-Discovery
# Disney -> https://brickset.com/minifigs/category-Disney
# DREAMZzz -> https://brickset.com/minifigs/category-DREAMZzz
# Dune -> https://brickset.com/minifigs/category-Dune
# DUPLO -> https://brickset.com/minifigs/category-DUPLO
# Editions -> https://brickset.com/minifigs/category-Editions
# Educational & Dacta -> https://brickset.com/minifigs/category-Educational-Dacta
# Elves -> https://brickset.com/minifigs/category-Elves
# Exo-Force -> https://brickset.com/minifigs/category-Exo-Force
# Fabuland -> https://brickset.com/minifigs/category-Fabuland
# FIRST LEGO League -> https://brickset.com/minifigs/category-FIRST-LEGO-League
# For Juniors -> https://brickset.com/minifigs/category-For-Juniors
# Fortnite -> https://brickset.com/minifigs/category-Fortnite
# FreeStyle -> https://brickset.com/minifigs/category-FreeStyle
# Friends -> https://brickset.com/minifigs/category-Friends
# Friends TV Series -> https://brickset.com/minifigs/category-Friends-TV-Series
# Fusion -> https://brickset.com/minifigs/category-Fusion
# Gabby's Dollhouse -> https://brickset.com/minifigs/category-Gabby-s-Dollhouse
# Games -> https://brickset.com/minifigs/category-Games
# Ghostbusters -> https://brickset.com/minifigs/category-Ghostbusters
# Harry Potter -> https://brickset.com/minifigs/category-Harry-Potter
# Hero Factory -> https://brickset.com/minifigs/category-Hero-Factory
# Hidden Side -> https://brickset.com/minifigs/category-Hidden-Side
# Holiday & Event -> https://brickset.com/minifigs/category-Holiday-Event
# Homemaker -> https://brickset.com/minifigs/category-Homemaker
# Horizon -> https://brickset.com/minifigs/category-Horizon
# Indiana Jones -> https://brickset.com/minifigs/category-Indiana-Jones
# Island Xtreme Stunts -> https://brickset.com/minifigs/category-Island-Xtreme-Stunts
# Jurassic World -> https://brickset.com/minifigs/category-Jurassic-World
# LEGENDS OF CHIMA -> https://brickset.com/minifigs/category-LEGENDS-OF-CHIMA
# LEGO Brand -> https://brickset.com/minifigs/category-LEGO-Brand
# LEGO Ideas -> https://brickset.com/minifigs/category-LEGO-Ideas
# LEGOLAND -> https://brickset.com/minifigs/category-LEGOLAND
# LEGOLAND Parks -> https://brickset.com/minifigs/category-LEGOLAND-Parks
# Lightyear -> https://brickset.com/minifigs/category-Lightyear
# Master Builder Academy -> https://brickset.com/minifigs/category-Master-Builder-Academy
# Minecraft -> https://brickset.com/minifigs/category-Minecraft
# Monkie Kid -> https://brickset.com/minifigs/category-Monkie-Kid
# Monster Fighters -> https://brickset.com/minifigs/category-Monster-Fighters
# NEXO KNIGHTS -> https://brickset.com/minifigs/category-NEXO-KNIGHTS
# Nike -> https://brickset.com/minifigs/category-Nike
# Ninja -> https://brickset.com/minifigs/category-Ninja
# NINJAGO -> https://brickset.com/minifigs/category-NINJAGO
# One Piece -> https://brickset.com/minifigs/category-One-Piece
# Overwatch -> https://brickset.com/minifigs/category-Overwatch
# Pharaoh's Quest -> https://brickset.com/minifigs/category-Pharaoh-s-Quest
# Pirates -> https://brickset.com/minifigs/category-Pirates
# Pirates of the Caribbean -> https://brickset.com/minifigs/category-Pirates-of-the-Caribbean
# Power Miners -> https://brickset.com/minifigs/category-Power-Miners
# Primo -> https://brickset.com/minifigs/category-Primo
# Prince of Persia -> https://brickset.com/minifigs/category-Prince-of-Persia
# Project Hail Mary -> https://brickset.com/minifigs/category-Project-Hail-Mary
# Promotional -> https://brickset.com/minifigs/category-Promotional
# Quatro -> https://brickset.com/minifigs/category-Quatro
# Queer Eye -> https://brickset.com/minifigs/category-Queer-Eye
# Racers -> https://brickset.com/minifigs/category-Racers
# Rock Raiders -> https://brickset.com/minifigs/category-Rock-Raiders
# Scala -> https://brickset.com/minifigs/category-Scala
# Scooby-Doo -> https://brickset.com/minifigs/category-Scooby-Doo
# Sonic the Hedgehog -> https://brickset.com/minifigs/category-Sonic-the-Hedgehog
# Space -> https://brickset.com/minifigs/category-Space
# SPEED CHAMPIONS -> https://brickset.com/minifigs/category-SPEED-CHAMPIONS
# Speed Racer -> https://brickset.com/minifigs/category-Speed-Racer
# Spider-Man -> https://brickset.com/minifigs/category-Spider-Man
# SpongeBob SquarePants -> https://brickset.com/minifigs/category-SpongeBob-SquarePants
# Sports -> https://brickset.com/minifigs/category-Sports
# Star Trek -> https://brickset.com/minifigs/category-Star-Trek
# Star Wars -> https://brickset.com/minifigs/category-Star-Wars
# Stranger Things -> https://brickset.com/minifigs/category-Stranger-Things
# Studios -> https://brickset.com/minifigs/category-Studios
# Super Heroes -> https://brickset.com/minifigs/category-Super-Heroes
# Super Mario -> https://brickset.com/minifigs/category-Super-Mario
# Technic -> https://brickset.com/minifigs/category-Technic
# Teenage Mutant Ninja Turtles -> https://brickset.com/minifigs/category-Teenage-Mutant-Ninja-Turtles
# The Angry Birds Movie -> https://brickset.com/minifigs/category-The-Angry-Birds-Movie
# The Hobbit and The Lord of the Rings -> https://brickset.com/minifigs/category-The-Hobbit-and-The-Lord-of-the-Rings
# The Incredibles -> https://brickset.com/minifigs/category-The-Incredibles
# The Legend of Zelda -> https://brickset.com/minifigs/category-The-Legend-of-Zelda
# The LEGO Movie -> https://brickset.com/minifigs/category-The-LEGO-Movie
# The LEGO Movie 2 -> https://brickset.com/minifigs/category-The-LEGO-Movie-2
# The LEGO NINJAGO Movie -> https://brickset.com/minifigs/category-The-LEGO-NINJAGO-Movie
# The Lone Ranger -> https://brickset.com/minifigs/category-The-Lone-Ranger
# The Powerpuff Girls -> https://brickset.com/minifigs/category-The-Powerpuff-Girls
# The Simpsons -> https://brickset.com/minifigs/category-The-Simpsons
# Time Cruisers -> https://brickset.com/minifigs/category-Time-Cruisers
# Town -> https://brickset.com/minifigs/category-Town
# Toy Story -> https://brickset.com/minifigs/category-Toy-Story
# Train -> https://brickset.com/minifigs/category-Train
# Trolls World Tour -> https://brickset.com/minifigs/category-Trolls-World-Tour
# Ultra Agents -> https://brickset.com/minifigs/category-Ultra-Agents
# Unikitty! -> https://brickset.com/minifigs/category-Unikitty!
# Universe -> https://brickset.com/minifigs/category-Universe
# Vidiyo -> https://brickset.com/minifigs/category-Vidiyo
# Vikings -> https://brickset.com/minifigs/category-Vikings
# Wednesday -> https://brickset.com/minifigs/category-Wednesday
# Western -> https://brickset.com/minifigs/category-Western
# Wicked -> https://brickset.com/minifigs/category-Wicked
# World Racers -> https://brickset.com/minifigs/category-World-Racers
# 2026 -> https://brickset.com/minifigs/year-2026
# 2025 -> https://brickset.com/minifigs/year-2025
# 2024 -> https://brickset.com/minifigs/year-2024
# 2023 -> https://brickset.com/minifigs/year-2023
# 2022 -> https://brickset.com/minifigs/year-2022
# 2021 -> https://brickset.com/minifigs/year-2021
# 2020 -> https://brickset.com/minifigs/year-2020
# 2019 -> https://brickset.com/minifigs/year-2019
# 2018 -> https://brickset.com/minifigs/year-2018
# 2017 -> https://brickset.com/minifigs/year-2017
# 2016 -> https://brickset.com/minifigs/year-2016
# 2015 -> https://brickset.com/minifigs/year-2015
# 2014 -> https://brickset.com/minifigs/year-2014
# 2013 -> https://brickset.com/minifigs/year-2013
# 2012 -> https://brickset.com/minifigs/year-2012
# 2011 -> https://brickset.com/minifigs/year-2011
# 2010 -> https://brickset.com/minifigs/year-2010
# 2009 -> https://brickset.com/minifigs/year-2009
# 2008 -> https://brickset.com/minifigs/year-2008
# 2007 -> https://brickset.com/minifigs/year-2007
# 2006 -> https://brickset.com/minifigs/year-2006
# 2005 -> https://brickset.com/minifigs/year-2005
# 2004 -> https://brickset.com/minifigs/year-2004
# 2003 -> https://brickset.com/minifigs/year-2003
# 2002 -> https://brickset.com/minifigs/year-2002
# 2001 -> https://brickset.com/minifigs/year-2001
# 2000 -> https://brickset.com/minifigs/year-2000
# 1999 -> https://brickset.com/minifigs/year-1999
# 1998 -> https://brickset.com/minifigs/year-1998
# 1997 -> https://brickset.com/minifigs/year-1997
# 1996 -> https://brickset.com/minifigs/year-1996
# 1995 -> https://brickset.com/minifigs/year-1995
# 1994 -> https://brickset.com/minifigs/year-1994
# 1993 -> https://brickset.com/minifigs/year-1993
# 1992 -> https://brickset.com/minifigs/year-1992
# 1991 -> https://brickset.com/minifigs/year-1991
# 1990 -> https://brickset.com/minifigs/year-1990
# 1989 -> https://brickset.com/minifigs/year-1989
# 1988 -> https://brickset.com/minifigs/year-1988
# 1987 -> https://brickset.com/minifigs/year-1987
# 1986 -> https://brickset.com/minifigs/year-1986
# 1985 -> https://brickset.com/minifigs/year-1985
# 1984 -> https://brickset.com/minifigs/year-1984
# 1983 -> https://brickset.com/minifigs/year-1983
# 1982 -> https://brickset.com/minifigs/year-1982
# 1981 -> https://brickset.com/minifigs/year-1981
# 1980 -> https://brickset.com/minifigs/year-1980
# 1979 -> https://brickset.com/minifigs/year-1979
# 1978 -> https://brickset.com/minifigs/year-1978
# 1977 -> https://brickset.com/minifigs/year-1977
# 1976 -> https://brickset.com/minifigs/year-1976
# 1975 -> https://brickset.com/minifigs/year-1975

# %% [markdown]
# ## Step 3
#
# We also need to store the base URL in a variable (https://brickset.com), since it's not in the href-property.
#
# Note that in the created list we don't only have links to every theme, but also to every year. Every minifig in a theme is also in a year, and visa versa.
#
# ![](images/minifig_part3.PNG)
#
# We don't need to download every minifig image twice! The goal of this step is filtering out all non-theme items (~years) in the list. This action reduces the list to 121 items.
#
# Try to use regex to check whether the first element of the tuple contains a year (4 digits).

# %%
import requests
from bs4 import BeautifulSoup
import re

# Base URL
base_url = "https://brickset.com"

# Request the page
url = base_url + "/browse/minifigs"
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36'}

response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')

# Find the content div
content_div = soup.find('div', class_='content')

# Create list of tuples (category name, full url)
all_categories = []

for link in content_div.find_all('a'):
    name = link.text.strip()
    href = link.get('href')
    
    if name and href and 'minifigs' in href:
        full_url = base_url + href
        all_categories.append((name, full_url))

# Filter out years using regex and list comprehension
# Years are 4 digits (like 2020, 2021, etc.)
themes = [(name, url) for name, url in all_categories 
          if not re.search(r'\b\d{4}\b', name)]

# Print results
print(f"Total items before filtering: {len(all_categories)}")
print(f"Themes after filtering out years: {len(themes)}")
print("\nFirst 10 themes:")
for name, url in themes[:10]:
    print(f"  {name} -> {url}")
# Out:
# Total items before filtering: 176
# Themes after filtering out years: 124
#
# First 10 themes:
#   Adventurers -> https://brickset.com/minifigs/category-Adventurers
#   Agents -> https://brickset.com/minifigs/category-Agents
#   Alpha Team -> https://brickset.com/minifigs/category-Alpha-Team
#   Animal Crossing -> https://brickset.com/minifigs/category-Animal-Crossing
#   Aquazone -> https://brickset.com/minifigs/category-Aquazone
#   Architecture -> https://brickset.com/minifigs/category-Architecture
#   Atlantis -> https://brickset.com/minifigs/category-Atlantis
#   Avatar -> https://brickset.com/minifigs/category-Avatar
#   Avatar The Last Airbender -> https://brickset.com/minifigs/category-Avatar-The-Last-Airbender
#   Back to the Future -> https://brickset.com/minifigs/category-Back-to-the-Future

# %% [markdown]
# Check your code.  Probably you didn't think of using list comprehension. In that case rewrite your solution.

# %%
# Up to you!
# Out:
# 172
# 121

# %% [markdown]
# ## Step 4
#
# Next we'll be doing something different than before: in stead of simply putting a URL in a variable and using that for the request, we'll write a function taking the URL as parameter. This way it's easier to reuse this function later on for all the urls in the list of categories.
#
#
# The downside of this when using a Jupyter notebook is if the function is in codeblock A and you call it in codeblock B, then running codeblock B *won't* recompile the function. You'll run the function as it was the last time you ran codeblock A.
#
# And what does this function do? We'll be looking at the following pages:
#
# ![](images/2022-03-08-16-09-11.png)
#
# As you can see the interesting part is in the section ```<section class="setlist minifiglist">```. All individual images are conveniently grouped in articles with class "set":
#
# ![](images/2022-03-08-16-17-53.png)
#
# Goal of this step is to define a function _**download_page(url)**_ that scrapes this information and stores it in a list of tuples.  The first element in the tuple is the link to the image file and the second element is the content of the attribute 'title'.

# %%
import requests
from bs4 import BeautifulSoup

def download_page(url):
   
    
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36'}
    
    try:
        # Request the page
        response = requests.get(url, headers=headers)
        
        # Parse HTML
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Find the minifig section
        minifig_section = soup.find('section', class_='setlist minifiglist')
        
        if not minifig_section:
            print("❌ Minifig section not found")
            return []
        
        # Find all minifig articles
        minifigs = minifig_section.find_all('article', class_='set')
        
        # Extract image URL and title from each minifig
        minifig_data = []
        
        for fig in minifigs:
            # Find the image tag
            img = fig.find('img')
            
            if img:
                # Get image URL (src attribute)
                img_url = img.get('src')
                
                # Get title (alt attribute)
                title = img.get('alt', '').strip()
                
                # If no alt text, try getting title from other elements
                if not title:
                    title_tag = fig.find('a', class_='title')
                    if title_tag:
                        title = title_tag.text.strip()
                
                minifig_data.append((img_url, title))
        
        return minifig_data
        
    except Exception as e:
        print(f"❌ Error downloading {url}: {e}")
        return []

# USE THIS CODE TO TEST YOUR FUNCTION
test_url = "https://brickset.com/minifigs/category-Adventurers"
images = download_page(test_url)

print(f"✅ Found {len(images)} minifigs")
print("\n📋 First 10 minifigs:")
print(*images[0:10], sep='\n')

# %%
# USE THIS CODE TO TEST YOUR FUNCTION
images = download_page("https://brickset.com/minifigs/category-Adventurers")
print(*images[0:10],sep='\n')
# Out:
# ('https://images.brickset.com/minifigs/large/adv001.jpg', 'adv001: Achu')
# ('https://images.brickset.com/minifigs/large/adv002.jpg', 'adv002: Alexis Sanister / Alexia Sinister')
# ('https://images.brickset.com/minifigs/large/adv027.jpg', 'adv027: Babloo')
# ('https://images.brickset.com/minifigs/large/adv033.jpg', 'adv033: Dr. Kilroy / Dr. Charles Lightning - Dark Gray Open Jacket, Black Legs, White Pith Helmet')
# ('https://images.brickset.com/minifigs/large/adv035.jpg', 'adv035: Dr. Kilroy / Dr. Charles Lightning - Green and Lime Vest, Green Legs, White Pith Helmet')
# ('https://images.brickset.com/minifigs/large/adv026.jpg', 'adv026: Dr. Kilroy / Dr. Charles Lightning - Green and Lime Vest, White Legs, White Pith Helmet')
# ('https://images.brickset.com/minifigs/large/adv006.jpg', 'adv006: Dr. Kilroy / Dr. Charles Lightning - White Shirt and Suspenders, Green Legs, White Pith Helmet')
# ('https://images.brickset.com/minifigs/large/adv040.jpg', 'adv040: Dr. Kilroy / Dr. Charles Lightning - White Shirt and Suspenders, Green Legs, White Pith Helmet, Brown Backpack')
# ('https://images.brickset.com/minifigs/large/adv046.jpg', 'adv046: Dragon Fortress Guard - Conical Helmet')
# ('https://images.brickset.com/minifigs/large/adv047.jpg', 'adv047: Dragon Fortress Guard - Conical Helmet, Quiver')

# %% [markdown]
# The output should look like this
#
# ![](images/minifig_part4.PNG)

# %% [markdown]
# ## Step 5
#
# From here we give you the code.
#
# That much is working. But there's another problem:
#
# ![](images/2022-03-08-16-32-19.png)
#
# Pagination. We're not looking at all minifigs, but only the ones that fitted on the page. There are two solutions:
#
# - Do some extra scraping, and get a list of all pages, calling the function on all these pages
# - Make the existing function recursive: if there is a "next page" link, get the list from that page and add it to the returned list.
#
# The second is the topic of the first chapter of the AI-course you'll be getting. Let's do a preview!

# %%
def download_page_recursive(url):
    
    page = requests.get(url)
    information = []
    soup = BeautifulSoup(page.content, "html.parser")

    results = soup.find("section", {"class": "setlist minifiglist"})
    # print(results.prettify())
    image_list = []

    articles = results.find_all("article", {"class": "set"})

    for article in articles:
        image = article.find("img", src=True)
        image_list.append( ( image["src"], image["title"] ) )

    # the new part:
    results = soup.find("li", {"class": "next"}) # look in the entire page, not just the center part
    if results != None:
        link = results.find("a", href=True)
        if link != None:
            image_list += download_page(link['href']) # add all returned links to the list we already had
        
    return image_list

images = download_page("https://brickset.com/minifigs/category-Adventurers")
print(len(images))

images = download_page_recursive("https://brickset.com/minifigs/category-Adventurers")
print(len(images))
# Out:
# 50
# 52

# %% [markdown]
# Five more, which checks out, because there are five minifigs on the second page. But what, so I hear you think, happens if there is a third page? Well, the second page will have a "Next" link as well, so the second page will ask the third page for a list, add that list to the list the second page made and return it to the function creating the list of the first page. And a fourth page? Let the third page handle that. Do note that this only works when the last page doesn't have a "Next"-link. If the last page were to have a link to the first page (circular pagination, so to speak) we'd have ourselves an infinite loop.
#
# Recursion is complicated, but it does great things. Just watch [this](https://www.youtube.com/watch?v=G_UYXzGuqvM) video. It won't, however, be in the exam for this course.
#
# Next up is running this recursive function on all the links we created earlier (in the code sample this variable is called 'pretty_links' You must adjust the name!). Do remember to add the base_url variable (adjust the name) to the url in the list.

# %%
all_images = []
for pretty_link in pretty_links[0:3]:
    images = download_page_recursive(base_url + pretty_link[1])
    all_images += [ (pretty_link[0], im[0], im[1]) for im in images]

print(all_images[:10])
print(all_images[-10:])
print(len(all_images))
# Out:
# [('Adventurers', 'https://images.brickset.com/minifigs/large/adv001.jpg', 'adv001: Achu'), ('Adventurers', 'https://images.brickset.com/minifigs/large/adv002.jpg', 'adv002: Alexis Sanister / Alexia Sinister'), ('Adventurers', 'https://images.brickset.com/minifigs/large/adv027.jpg', 'adv027: Babloo'), ('Adventurers', 'https://images.brickset.com/minifigs/large/adv033.jpg', 'adv033: Dr. Kilroy / Dr. Charles Lightning - Dark Gray Open Jacket, Black Legs, White Pith Helmet'), ('Adventurers', 'https://images.brickset.com/minifigs/large/adv035.jpg', 'adv035: Dr. Kilroy / Dr. Charles Lightning - Green and Lime Vest, Green Legs, White Pith Helmet'), ('Adventurers', 'https://images.brickset.com/minifigs/large/adv026.jpg', 'adv026: Dr. Kilroy / Dr. Charles Lightning - Green and Lime Vest, White Legs, White Pith Helmet'), ('Adventurers', 'https://images.brickset.com/minifigs/large/adv006.jpg', 'adv006: Dr. Kilroy / Dr. Charles Lightning - White Shirt and Suspenders, Green Legs, White Pith Helmet'), ('Adventurers', 'https://images.brickset.com/minifigs/large/adv040.jpg', 'adv040: Dr. Kilroy / Dr. Charles Lightning - White Shirt and Suspenders, Green Legs, White Pith Helmet, Brown Backpack'), ('Adventurers', 'https://images.brickset.com/minifigs/large/adv046.jpg', 'adv046: Dragon Fortress Guard - Conical Helmet'), ('Adventurers', 'https://images.brickset.com/minifigs/large/adv047.jpg', 'adv047: Dragon Fortress Guard - Conical Helmet, Quiver')]
# [('Alpha Team', 'https://img.bricklink.com/ItemImage/MN/0/alp022.png', 'alp022: Ogel Minion - Mission Deep Freeze'), ('Alpha Team', 'https://img.bricklink.com/ItemImage/MN/0/alp019.png', 'alp019: Ogel Minion - Mission Deep Sea'), ('Alpha Team', 'https://img.bricklink.com/ItemImage/MN/0/alp006.png', 'alp006: Ogel Minion Commander'), ('Alpha Team', 'https://img.bricklink.com/ItemImage/MN/0/alp018.png', 'alp018: Ogel Minion Commander - Emblem on Torso'), ('Alpha Team', 'https://img.bricklink.com/ItemImage/MN/0/alp033.png', 'alp033: Ogel Minion, Super Ice Drone - Mission Deep Freeze'), ('Alpha Team', 'https://img.bricklink.com/ItemImage/MN/0/alp009.png', 'alp009: Radia'), ('Alpha Team', 'https://img.bricklink.com/ItemImage/MN/0/alp028.png', 'alp028: Radia - Mission Deep Freeze'), ('Alpha Team', 'https://img.bricklink.com/ItemImage/MN/0/alp012.png', 'alp012: Radia - Mission Deep Sea'), ('Alpha Team', 'https://img.bricklink.com/ItemImage/MN/0/alp007.png', 'alp007: Tee Vee'), ('Alpha Team', 'https://img.bricklink.com/ItemImage/MN/0/alp030.png', 'alp030: Zed')]
# 117

# %% [markdown]
# Did you note the "[0:3]" at the end of the for-loop? That is there for testing purposes. A loop like this never works on the first try and this way you can test it without always running it on the full list of a couple of thousand images. And we left it here because for this example the 119 links we have are plenty. There is no need to run all categories and download a list of 13.000 links...
#
# So now we have the list. Maybe we want it in a CSV-file? That would be a good way of storing it for later usage.

# %%
import csv

header = ['Category', 'URL', 'name']

with open('to_download.csv', 'w', encoding='UTF8', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerows(all_images)

# %% [markdown]
# Now all we need to do in the Jupyter notebook where we're downloading the images is read the csv (using CSV-reader) and recreate the exact same list-variable we had before. Which seems like a waste, isn't there a way to store the variable as a file and simply re-import the file everytime we need the file? Like we do with vegetables: we put them in a jar with a mixture of salt and vinegar to keep them until the dark days in winter when we need a homemade Bicky-burger with a homemade pickle.
#
# (The keyword here is [pickle](https://docs.python.org/3/library/pickle.html).)
#
# ([And another link that is much easier to understand](https://dodona.ugent.be/nl/activities/58032010/).)

# %%
import pickle

pickle.dump( all_images, open( "all_images.p", "wb" ) )

# %% [markdown]
# Opening a jar with condiments can be very hard. Is the same true for opening a pickle-file?

# %%
my_images = pickle.load( open( "all_images.p", "rb" ) )

print(my_images[:10])
print(my_images[-10:])
print(len(my_images))
# Out:
# [('Adventurers', 'https://images.brickset.com/minifigs/large/adv001.jpg', 'adv001: Achu'), ('Adventurers', 'https://images.brickset.com/minifigs/large/adv002.jpg', 'adv002: Alexis Sanister / Alexia Sinister'), ('Adventurers', 'https://images.brickset.com/minifigs/large/adv027.jpg', 'adv027: Babloo'), ('Adventurers', 'https://images.brickset.com/minifigs/large/adv033.jpg', 'adv033: Dr. Kilroy / Dr. Charles Lightning - Dark Gray Open Jacket, Black Legs, White Pith Helmet'), ('Adventurers', 'https://images.brickset.com/minifigs/large/adv035.jpg', 'adv035: Dr. Kilroy / Dr. Charles Lightning - Green and Lime Vest, Green Legs, White Pith Helmet'), ('Adventurers', 'https://images.brickset.com/minifigs/large/adv026.jpg', 'adv026: Dr. Kilroy / Dr. Charles Lightning - Green and Lime Vest, White Legs, White Pith Helmet'), ('Adventurers', 'https://images.brickset.com/minifigs/large/adv006.jpg', 'adv006: Dr. Kilroy / Dr. Charles Lightning - White Shirt and Suspenders, Green Legs, White Pith Helmet'), ('Adventurers', 'https://images.brickset.com/minifigs/large/adv040.jpg', 'adv040: Dr. Kilroy / Dr. Charles Lightning - White Shirt and Suspenders, Green Legs, White Pith Helmet, Brown Backpack'), ('Adventurers', 'https://images.brickset.com/minifigs/large/adv046.jpg', 'adv046: Dragon Fortress Guard - Conical Helmet'), ('Adventurers', 'https://images.brickset.com/minifigs/large/adv047.jpg', 'adv047: Dragon Fortress Guard - Conical Helmet, Quiver')]
# [('Alpha Team', 'https://img.bricklink.com/ItemImage/MN/0/alp022.png', 'alp022: Ogel Minion - Mission Deep Freeze'), ('Alpha Team', 'https://img.bricklink.com/ItemImage/MN/0/alp019.png', 'alp019: Ogel Minion - Mission Deep Sea'), ('Alpha Team', 'https://img.bricklink.com/ItemImage/MN/0/alp006.png', 'alp006: Ogel Minion Commander'), ('Alpha Team', 'https://img.bricklink.com/ItemImage/MN/0/alp018.png', 'alp018: Ogel Minion Commander - Emblem on Torso'), ('Alpha Team', 'https://img.bricklink.com/ItemImage/MN/0/alp033.png', 'alp033: Ogel Minion, Super Ice Drone - Mission Deep Freeze'), ('Alpha Team', 'https://img.bricklink.com/ItemImage/MN/0/alp009.png', 'alp009: Radia'), ('Alpha Team', 'https://img.bricklink.com/ItemImage/MN/0/alp028.png', 'alp028: Radia - Mission Deep Freeze'), ('Alpha Team', 'https://img.bricklink.com/ItemImage/MN/0/alp012.png', 'alp012: Radia - Mission Deep Sea'), ('Alpha Team', 'https://img.bricklink.com/ItemImage/MN/0/alp007.png', 'alp007: Tee Vee'), ('Alpha Team', 'https://img.bricklink.com/ItemImage/MN/0/alp030.png', 'alp030: Zed')]
# 117

# %% [markdown]
# No.
